# %% [markdown]
# ## Streamlit
# -
# - Streamlit is a python tool to help turn python scripts into webpages (Dashboards)
# -
# - instead of learning about Front end development entirely new subject
# - use this library to build front ends

# %% [markdown]
# ```
#
# st.title()
# st.write()
# st.slider()
# st.line_chart()

# %% [markdown]
# - can build data dashboards
# - demo applications
# - simple forms
# - portfolio projects
# - prototyping

# %%
pip install streamlit

# %% [markdown]
# - You can only run the streamlit using a script
# - create a script with the streamlit code
# - go to terminal
# - type: streamlit run <filename.py>

# %%
import streamlit as st

# %%
st.title("First Streamlit App")
# Out:
# 2026-07-13 11:13:09.395 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 11:13:09.812
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-07-13 11:13:09.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 11:13:09.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
