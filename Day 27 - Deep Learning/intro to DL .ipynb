# %% [markdown]
# ## Deep Learning

# %% [markdown]
# Deep learning is a subset of **ML** that mimics the structure and function of the **human brain** through **artificial neural networks** (ANN)

# %% [markdown]
# Resources to learn from:
# - [Tutorial On DL](https://www.analyticsvidhya.com/blog/2021/05/a-comprehensive-tutorial-on-deep-learning-part-1/)
# - [AI vs ML vs DL IBM](https://www.ibm.com/think/topics/ai-vs-machine-learning-vs-deep-learning-vs-neural-networks)
# - [DL by IBM](https://www.ibm.com/think/topics/deep-learning)

# %% [markdown]
# - Up to ML we had a lot of ideas about how a model makes its prediction
# - but once we started using NNs
#     - things started to become blurry
#
# - at this time, we can judge NNs as well
# -
# - but now technology is far superior than just NNs
# -
# - What architectures are being used in the latest AI models?
#     - In GenAI lessons, we will have a look
#     - Transformers

# %% [markdown]
# Relationship with ML and AI:
#
# - **AI**: The broader concept of machines performing tasks that require human intelligence.
#     - a more general term - Umbrella term - anything can be called AI
#     - if a machine demonstrates intelligent behaviour
#     - if a machine perform tasks that typically humans do
#     -

# %% [markdown]
# - **ML**: A subset of AI that involves training algorithms to make predictions without being explicitly programmed.
#     - Specifically where machines learn from data (labelled or unlabelled)
#     - instead of writing rules for what should be the prediction, you feed an algorithm data, and let it decide itself
#     - **Supervised** - Labelled data - e.g. Learning from a teacher
#     - **Unsupervised** - Unlabelled data - e.g. Finding hidden patterns in data
#     - **Reinforcement** - Rewards and Punishment points - e.g. Learning from trail and error - Data from environment, to teach the machine/agent
#     -

# %% [markdown]
# - **DL**: A subset of ML focused on learning from data using NNs with multiple layers.
#     - We try to create machines that mimic human intelligence
#     - We use neurons that are based on human brain cells
#     - We use ANNs to make predictions
#
# - The more data you add, more perfornance you get
#
#     - **Computer Vision**
#         - train computers to analyse and interpret visual data
#
#     - **Natural Language Processing**
#         - teach machines to **understand** natural language, and **generate** as well
#
#     - **Robotics**
#         - deal with hardware - teaching physical robots to act like agents
#
#     - **GenAI** - we use DNNs to make decisions
#         - Image gen
#         - text, audio
#         - video gen
#         - **LLMs** - Large Language Model

# %% [markdown]
# - The seperation boundary becomes a bit more blurred. Generally GenAI and LLMs are considered a part of DL

# %% [markdown]
# <div style="background-color: lightblue; color: black; padding: 4px;">
#     <h4> # Differences Between ML and DL
# </h4> </div>

# %% [markdown]
# | **Aspect** | **ML** | **DL** |
# |---------------------|---------------------|---------------------|
# | **Level of Complexity** | Relies on manual feature engineering and **simpler models**. | Uses **DNNs** to learn directly from data. |
# | **Data Requirements** | Performs well with small to medium datasets. | Requires **large datasets** for optimal performance. |
# | **Feature Engineering** | Manual feature extraction by domain experts. | Features are automatically extracted during training. |
# | **Computational Power** | Works on regular CPUs; requires less computational power. | Needs GPUs/TPUs due to high computation demands. |
# | **Algorithm Structure** | Includes decision trees, SVMs, regression, etc. | Uses CNNs, RNNs, transformers, and deep architectures. |
# | **Applications** | Structured data tasks like fraud detection or segmentation. | Unstructured data tasks like image and speech recognition. |
# | **Training Time** | Typically **faster** to train. | **Longer training times** due to model complexity. |
# | **Interpretability** | Models like decision trees are **interpretable**. | Operates as a **"black box"** with limited interpretability. |
# | **Hardware Dependency** | Can run on traditional hardware setups. | Requires specialized hardware like GPUs/TPUs. |
# | **Performance** | Good for smaller datasets and simple tasks. | Excels with large, complex datasets and unstructured data. |

# %% [markdown]
# ## Neuron

# %% [markdown]
# - in biology, neuron = brain cell
# -
# - In CS, Neuron = a single unit of a NN
# -

# %% [markdown]
# A neuron in a **NN** mimics a biological neuron in the brain. It is the basic unit that processes information.
#
# - What is a Neuron?
# - A nerve cell, is an excitable cell that fires electric signals
# - Building blocks of human brain

# %% [markdown]
# - BIOLOGY: A **neural circuit** is a population of neurons interconnected by **synapses** to carry out a specific function when activated.
#
# - From "Texture of the Nervous System of Man and the Vertebrates" by Santiago Ramon y Cajal.

# %% [markdown]
# <div style="background-color: lightblue; color: black; padding: 4px;">
#     <h4> Model of a Neuron - Perceptron

# %% [markdown]
# - [Resource](https://www.w3schools.com/ai/ai_perceptrons.asp)
#
# We wanted to model this neuron. To mimic how humans think.
#
# - Frank Rosenblatt (1928 - 1971) was an American psychologist notable in the field of AI.
# -
# - In 1957 he started something really big. He "invented" a Perceptron program, on an IBM 704 computer at Cornell Aeronautical Laboratory
# -
# - Scientists had discovered that brain cells (Neurons) receive **input** from our **senses** by electrical signals.
# -
# - use electrical signals to store information, and to make decisions based on previous input.

# %% [markdown]
# Frank Rosenblatt suggested this algorithm:
#
# 1. Set a threshold value ---> Decision Boundary
# 2. Multiply all inputs with its weights ---> Dot Product
# 3. Sum all the results ---> Weighted Sum - you add according to the weightage/importance
# 4. Activate the output ---> whether the threshold is met or not
# - This was called a Perceptron - an **Artificial Neuron**.

# %% [markdown]
# - A NN in its simplest form - an ANN unit

# %% [markdown]
# **Perceptron Example**: [Learn about the algorithm](https://www.w3schools.com/ai/ai_perceptrons.asp)
#
# 1. Set a threshold value
# 2. Multiply all inputs with its weights
# 3. Sum all the results
# 4. Activate the output
# - **Make a decision, whether you want to go to a concert**
#
# Criteria | Input (binary) | Weight (out of 1)
# ----------|-----------|-----------
# Artists | x1 = 0 or 1 | w1 = 0.9
# Weather | x2 = 0 or 1 | w2 = 0.7
# Friend | x3 = 0 or 1 | w3 = 0.5
# Food | x4 = 0 or 1 | w4 = 0.3
# Drink | x5 = 0 or 1 | w5 = 0.4

# %%
import numpy as np

inputs = np.array([1, 1, 0, 0, 1])
weights = np.array([0.9, 0.7, 0.5, 0.3, 0.4])
threshold = 1.5

product = inputs * weights
weighted_sum = sum(product)

def go_to_concert(x):
    if x >= threshold:
        return "Let's Go!!"
    else:
        return "No, thanks."

go_to_concert(weighted_sum)
# Out:
# "Let's Go!!"

# %%
def decision(artist, weather, friend, food, drink, threshold = 1.5):
    inputs = np.array([artist, weather, friend, food, drink])
    weights = np.array([0.9, 0.7, 0.5, 0.3, 0.4])

    product = inputs * weights
    weighted_sum = sum(product)

    if weighted_sum >= 1.5:
        return "Let's Go!!"
    else:
        return "No, thanks."
    
decision(1, 0, 1, 0, 0)
# Out:
# 'No, thanks.'
