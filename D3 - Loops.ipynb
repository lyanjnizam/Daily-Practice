# %% [markdown]
# Loops Practice
#
# -

# %%
# say your name 100 times

print('''Lya
''' * 100)
# Out:
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya

# %%
for i in range(100):
    print("Lya")
# Out:
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
# Lya
