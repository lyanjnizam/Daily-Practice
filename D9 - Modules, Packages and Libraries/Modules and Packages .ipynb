# %% [markdown]
# # Modules and Packages

# %% [markdown]
# - Modularity
#     - modular design - create different modules
#     - separate modules (files) to handle separate things
#
# - Reusability
#     - use an already written piece of code again and again
#     -
#
# - we have pre-written libraries of code in python
# - we use the import keyword to bring their context into program
# -

# %% [markdown]
# - A `MODULE` is a single file - like a single python script
# - `PACKAGE`
#     - a folder that holds multiple related files together
#     - multiple modules can exist in a package
# - `LIBRARY` are packages that we can install and use
#     - Bundles **packages** and **modules** together to solve a big, specific problem
#     - a library can hold multiple packages too
#     - a Giant Tool box
#     - we use the `pip` package of python, to install a library
#     - example:
#         - `pip` install `requests` `pillow` `numpy` `pandas`
#
# - Library examples:
#     - `requests` - used to connect to internet
#     - `numpy` - used for Numbers, numerical operation
#     - `pandas` - used for data analysis, deals with tabular data as well
#     - `matplotlib` - used for creating visuals like bar graph, line chart etc
#     - there are libraries for every single thing you can imagine in python
#
# - Python, open the folder/file and let me use the tools inside
#     - import tkinter
#     - import requests
#     -

# %% [markdown]
# #### common files in Projects or Libraries
#
# `__init__.py` ---> Dunder Files
# - the Receptionist
# - every time you import the package with init inside, the init.py runs automatically
# - existence of this file, tells python that this is an official packages
# - i.e. its a library we can use
# - this script automatically runs when we import the package
# -
# `__main__.py`
# - the Command Center of the package
# - This is like a switch you have to turn ON
# - you execute this file, to start something
#     - example:
#         - a multi agent system - has a lot of programs
#         - you want to execute some specific functions
#         - you save those in the main, and execute the main
#         - main will execute all those functions automatically
# - main.py is a script
#     - how do we execute scripts?
#     - go to terminal
#     - go to the folder where the scripts exists
#     - write: `python <script name.py>`
#     - another is to download a RUNNER Extension in VS Code
#
# - In any module file, if there is a function, it will be executed when you import the module(script)
#     - what shall we do
#     - whatever program there is to run in a script, we will keep it in a code block of this:
#         - `if __name__ == "__main__":`

# %% [markdown]
# ### Exercise
# 1. Please create a script file 'greet' that has a function inside
#     - hello() - should print a hello message
# 2. Create the two folders as shown
# 3.

# %%
import my_library as lib
# Out:
# Welcome to my Library! ^_^

# %%
lib.greet.hello()
# Out:
# 'Hello, Human?!'

# %%
lib.my_arthematic.div(10, 2)
# Out:
# 'Ask your dad! ;( ..... 5.0'

# %%
import test_project.greet as greeting

greeting.morning()
# Out:
# 'Good morning, WAKEE UPP Human?!!!'

# %%
from test_project import my_arthematic

my_arthematic.mul(5, 5)
# Out:
# 'Ask yourself! ;( ..... 25'

# %% [markdown]
# ### Micro School Management System Project
# - Discuss:
#     - What things should be there?
#     - Requirement:
#         - Website - for school to be visible
#         - Records:
#             - information of every person involved: teacher, student, staff, security guards, chef, janitor
#                 - can have different role
#                     - different responsibilities
#                     - different data that is important
#         - Record Updations:
#             - get records
#             - modify records
#             - delete records
#         - Data Analysis of the data we are saving in databases
#         - Adding other code for new things that are happening
#         - there can be much much more

# %% [markdown]
# #### Guidance on How to create projects:
# 1. Creating a folder - Packages - name it properly - (camel case preferred)
# 2. Problem Scoping/Statement - is where you decide what to achieve
#     - also the part that decides what not to do
#     - PS: create different classes for different roles in the school
#         - We research and find what the roles exactly do and then:
#         - add as many functions for those roles as possible
# 3. Setting up an Architecture:
#     - create a clean folder structure
#     -
# 4. creating the files and start coding from the core modules
#     - e.g. models are core module here because all important classes will be there
#     - we could break the models as well ---- teacher_model.py, student_model.py etc
#     -
# 5. Execute the main.py file to run the software

# %% [markdown]
# ##### Architecture
# ```
# SchoolManagementSystem
# |
# |---- init.py -> will run automatically, when you import the SMS package
# |---- main.py -> Entry point to the application
# |---- models.py -> model
# |---- manager.py -> View and controller

# %% [markdown]
# ```
# |---- init.py -> will run automatically, when you import the SMS package
# - init does not matter much when we are running the scripts
# - if we decide to use this package in our notebooks, then we will see the init being used a lot
# - every time we import the SMS we will be executing init automatically
# |---- main.py -> Entry point to the application

# %% [markdown]
# - in software architecture is important
#     - it is different from the programming paradigm that we use
#     -
#
# - The architecture - is not always related to OOP
#     - our architecture right now is that of
#         - MVC - Model View Controller type architecture
#
# - Programming Paradigm - Philosophy, a way of doing things
#     - example:
#         - Object Oriented Programming

# %%
import SchoolManagementSystem
# Out:
# School Management System activated....
