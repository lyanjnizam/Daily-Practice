# %% [markdown]
# # Graphical User Interface
# - Front end
# - for this, the most common language in the world ---> Javascript
# - html, css, js for this purpose
# -
# - In python we follow two ways to deploy applications for testing
# -
# - Tkinter ------ Gradio
# -

# %%
# Tkinter --- Built-in python - no new installation is needed
import tkinter as tk # aliases

# create a blank window
window = tk.Tk() # class is used to create the main application window

# created some text, to attach with the window
greeting = tk.label(window, text = "Hello User Interface!")

# packing - take the greeting, and put it on the window
greeting.pack()

# Keeps the window open
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       2 import tkinter as tk # aliases
#       4 # create a blank window
# ----> 5 window = tk.Tk() # class is used to create the main application window
#       7 # created some text, to attach with the window
#       8 greeting = tk.label(window, text = "Hello User Interface!")
#
# File /usr/local/python/3.12.1/lib/python3.12/tkinter/__init__.py:2340, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2338         baseName = baseName + ext
#    2339 interactive = False
# -> 2340 self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2341 if useTk:
#    2342     self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# ## Gradio
# -
